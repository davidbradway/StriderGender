# %%
import pandas as pd
import gender_guesser.detector as gender
d = gender.Detector()

# %%
#riders.json created from table at https://www.striderbikes.com/charlotte
df = pd.read_json('riders.json')
df['Gender'] = df.apply(lambda row: d.get_gender(row.FirstName), axis=1)
df.head()
# Out:
#                             Class FirstName  LastName  Number  Rank   Gender
# 0  2&Under Class Total Riders: 55   Anthony     Kenny     122     1     male
# 1  2&Under Class Total Riders: 55    Legend  Arellano     101     2  unknown
# 2  2&Under Class Total Riders: 55     Brady     Baker     111     3     male
# 3  2&Under Class Total Riders: 55    Kipton   Tonzola     143     4  unknown
# 4  2&Under Class Total Riders: 55      Dean  Sickelka     150     5     male

# %%
df['Gender'].value_counts()
# Out:
# male           35
# unknown        10
# female          4
# mostly_male     3
# Name: Gender, dtype: int64

# %%
df[df['Gender'].str.match('female')]
# Out:
#                                     Class FirstName  LastName  Number  Rank  \
# 25  3 Year Old 12s Class Total Riders: 45     Maria  Nikitina     110    10
# 30  3 Year Old 12s Class Total Riders: 45     Ellie      Gaul     139    15
# 31  3 Year Old 12s Class Total Riders: 45       Eli   Paschke     103    16
# 50         14x Open Class Total Riders: 9    Sophia  Piechnik     104     6
#
#     Gender
# 25  female
# 30  female
# 31  female
# 50  female

# %%
df[df['Gender'].str.match('unknown')]
# Out:
#                                     Class FirstName    LastName  Number  Rank  \
# 1          2&Under Class Total Riders: 55    Legend    Arellano     101     2
# 3          2&Under Class Total Riders: 55    Kipton     Tonzola     143     4
# 6          2&Under Class Total Riders: 55   Beckham        Bell     152     7
# 9          2&Under Class Total Riders: 55     Wells     Griffin     115    10
# 17  3 Year Old 12s Class Total Riders: 45    D'Nero   Willbrich     133     2
# 20  3 Year Old 12s Class Total Riders: 45     Valor     Conners     142     5
# 21  3 Year Old 12s Class Total Riders: 45    Gunner        Lusk     141     6
# 23  3 Year Old 12s Class Total Riders: 45   Kinsley    Villiard     135     8
# 33  4 Year Old 12s Class Total Riders: 35     Lliam    Benjamin     133     2
# 48         14x Open Class Total Riders: 9    Agniya  Kuzychenko     108     4
#
#      Gender
# 1   unknown
# 3   unknown
# 6   unknown
# 9   unknown
# 17  unknown
# 20  unknown
# 21  unknown
# 23  unknown
# 33  unknown
# 48  unknown

# %%
df[df['Gender'].str.match('mostly_male')]
# Out:
#                                     Class FirstName    LastName  Number  Rank  \
# 19  3 Year Old 12s Class Total Riders: 45     Logan     Montero     116     4
# 27  3 Year Old 12s Class Total Riders: 45   Charlie  Williamson     144    12
# 35  4 Year Old 12s Class Total Riders: 35    Parker      Harmon     105     4
#
#          Gender
# 19  mostly_male
# 27  mostly_male
# 35  mostly_male

# %%
df[df['Gender'].str.match('male')]
# Out:
#                                     Class FirstName  LastName  Number  Rank  \
# 0          2&Under Class Total Riders: 55   Anthony     Kenny     122     1
